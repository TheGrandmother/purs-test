# %%
import matplotlib.pyplot as plt
import numpy as np
from math import exp

x=np.linspace(0.00001,2,100)
y=np.vectorize(lambda x: exp(-1.0 * (1/x)))(x)
y=np.vectorize(lambda x: exp(-x))(x)

plt.plot(x,y)
plt.show()
